# %%
import pandas as pd
v=pd.read_csv('housing.csv')
v
# Out:
# /usr/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /usr/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# 5        -122.25     37.85                52.0        919.0           213.0
# 6        -122.25     37.84                52.0       2535.0           489.0
# ...

# %%
v.info()
v.describe()
v.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-7398b844bb3a> in <module>()
# ----> 1 v.info()
#       2 v.describe()
#       3 v.shape
#
# NameError: name 'v' is not defined

# %%
ndf=v.head(5)
display(ndf)
mdf=v.tail(5)
display(mdf)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY
# ...

# %%
print("Unique values = "+str(len(v.ocean_proximity.unique())))
v.ocean_proximity.unique()
# Out:
# Unique values = 5
# array(['NEAR BAY', '<1H OCEAN', 'INLAND', 'NEAR OCEAN', 'ISLAND'],
#       dtype=object)

# %%
v.hist(column='median_income')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7ff4a67e6080>]],
#       dtype=object)

# %%
g = v.groupby('ocean_proximity')['population'].mean()
g
# Out:
# ocean_proximity
# <1H OCEAN     1520.290499
# INLAND        1391.046252
# ISLAND         668.000000
# NEAR BAY      1230.317467
# NEAR OCEAN    1354.008653
# Name: population, dtype: float64

# %%
print('INLAND') if g['INLAND']>g['NEAR OCEAN'] else print('NEAR OCEAN')  #which is large in population
# Out:
# INLAND

# %%
print("Inland is larger by :" + str(g['INLAND']-g['NEAR OCEAN']))
# Out:
# Inland is larger by :37.037599357888666

# %%
#correlaed attrib
import matplotlib.pyplot as plt
# %matplotlib qt
print(v['total_rooms'].corr(v['median_income']))
plt.scatter(v['total_rooms'].head(50),v['median_income'].head(50))
#plt.show()
# Out:
# 0.19804964508460998

# %%
#Q5
m=v.loc[v['ocean_proximity'] == 'INLAND']

# %%
s = 25 ** m['population']
plt.scatter(m['longitude'],m['latitude'],c=m['median_house_value'],cmap = plt.get_cmap('jet'),alpha=0.2,s=s)
plt.colorbar()
#plt.show()
